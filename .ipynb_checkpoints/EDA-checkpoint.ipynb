# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /Users/reidbongard/opt/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv('./Cleaned_Data/dart_and_feature_data.csv', index_col=0)

# %%
df.head()
# Out:
#                               RT_LMP    RT_MCC     RT_MCE    RT_MCL  RT_MGHG  \
# 2022-08-01 07:00:00+00:00  83.619805  0.460775  77.053724  6.105308      0.0
# 2022-08-01 08:00:00+00:00  88.222433 -3.238011  84.239468  7.220975      0.0
# 2022-08-01 09:00:00+00:00  79.830854 -0.873706  74.130738  6.573821      0.0
# 2022-08-01 10:00:00+00:00  80.461047 -0.303146  73.963383  6.800811      0.0
# 2022-08-01 11:00:00+00:00  83.780540  0.000000  76.490646  7.289892      0.0
#
#                              DA_LMP   DA_MCC    DA_MCE   DA_MCL  DA_MGHG  ...  \
# 2022-08-01 07:00:00+00:00  76.04114 -4.33270  82.15664 -1.78280      0.0  ...
# 2022-08-01 08:00:00+00:00  76.73656 -2.02852  78.76508  0.00000      0.0  ...
# 2022-08-01 09:00:00+00:00  74.60014 -2.18867  78.20431 -1.41550      0.0  ...
# 2022-08-01 10:00:00+00:00  74.37176 -1.41315  77.22910 -1.44418      0.0  ...
# 2022-08-01 11:00:00+00:00  74.57854 -2.37722  78.36636 -1.41059      0.0  ...
#
#                            weekend  hour  Total_Solar_Forecast_RTD  \
# 2022-08-01 07:00:00+00:00        0     7                       0.0
# 2022-08-01 08:00:00+00:00        0     8                       0.0
# 2022-08-01 09:00:00+00:00        0     9                       0.0
# 2022-08-01 10:00:00+00:00        0    10                       0.0
# 2022-08-01 11:00:00+00:00        0    11                       0.0
#
#                            Total_Wind_Forecast_RTD  \
# 2022-08-01 07:00:00+00:00                  1297.41
# 2022-08-01 08:00:00+00:00                  1098.18
# 2022-08-01 09:00:00+00:00                  1261.07
# 2022-08-01 10:00:00+00:00                   863.51
# 2022-08-01 11:00:00+00:00                   574.00
#
#                            Total_Wind_Solar_Forecast_RTD  \
# 2022-08-01 07:00:00+00:00                        1297.41
# 2022-08-01 08:00:00+00:00                        1098.18
# 2022-08-01 09:00:00+00:00                        1261.07
# 2022-08-01 10:00:00+00:00                         863.51
# 2022-08-01 11:00:00+00:00                         574.00
#
#                            renew_forecast_error  \
# 2022-08-01 07:00:00+00:00                 -3.86
# 2022-08-01 08:00:00+00:00                 73.08
# 2022-08-01 09:00:00+00:00               -121.73
# 2022-08-01 10:00:00+00:00               -233.74
# 2022-08-01 11:00:00+00:00                 79.53
#
#                            prev_day_renew_forecast_error  prev_day_Export  \
# 2022-08-01 07:00:00+00:00                            NaN              NaN
# 2022-08-01 08:00:00+00:00                            NaN              NaN
# 2022-08-01 09:00:00+00:00                            NaN              NaN
# 2022-08-01 10:00:00+00:00                            NaN              NaN
# 2022-08-01 11:00:00+00:00                            NaN              NaN
#
#                            prev_day_Generation  prev_day_Import
# 2022-08-01 07:00:00+00:00                  NaN              NaN
# 2022-08-01 08:00:00+00:00                  NaN              NaN
# 2022-08-01 09:00:00+00:00                  NaN              NaN
# 2022-08-01 10:00:00+00:00                  NaN              NaN
# 2022-08-01 11:00:00+00:00                  NaN              NaN
#
# [5 rows x 40 columns]

# %%
df.columns
# Out:
# Index(['RT_LMP', 'RT_MCC', 'RT_MCE', 'RT_MCL', 'RT_MGHG', 'DA_LMP', 'DA_MCC',
#        'DA_MCE', 'DA_MCL', 'DA_MGHG', 'Export', 'Generation', 'Import',
#        'NP15_Solar_Renewable Forecast RTD', 'NP15_Wind_Renewable Forecast RTD',
#        'SP15_Solar_Renewable Forecast RTD', 'SP15_Wind_Renewable Forecast RTD',
#        'ZP26_Solar_Renewable Forecast RTD', 'renewables_rtd',
#        'HLY-CLDH-NORMAL_USW00023129', 'HLY-CLDH-NORMAL_USW00023174',
#        'HLY-CLDH-NORMAL_USW00023188', 'HLY-HTDH-NORMAL_USW00023129',
#        'HLY-HTDH-NORMAL_USW00023174', 'HLY-HTDH-NORMAL_USW00023188',
#        'HLY-TEMP-NORMAL_USW00023129', 'HLY-TEMP-NORMAL_USW00023174',
#        'HLY-TEMP-NORMAL_USW00023188', 'DART', 'friday', 'weekend', 'hour',
#        'Total_Solar_Forecast_RTD', 'Total_Wind_Forecast_RTD',
#        'Total_Wind_Solar_Forecast_RTD', 'renew_forecast_error',
#        'prev_day_renew_forecast_error', 'prev_day_Export',
#        'prev_day_Generation', 'prev_day_Import'],
#       dtype='object')

# %% [markdown]
# # View distribution of variables

# %%
view_cols = ['RT_LMP', 'DA_LMP', 'Export', 
             'Generation', 'Import', 'Total_Wind_Solar_Forecast_RTD', 
             'renew_forecast_error']


fig, axs = plt.subplots(2, 3)

for i in range(len(axs.flatten())):
    axs.flatten()[i] = plt.hist(view_cols[i], data=df)
